# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
houses = pd.read_csv("house_cleaned_001.csv")
flats = pd.read_csv("flats_cleaned_001.csv")

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
# shuffle the data
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                   property_name property_type         society  \
# 0  1 Bedroom House for sale in Sector 8 Gurgaon         house     independent
# 1              1 BHK Flat in Sector 36A Gurgaon          flat  avl 36 gurgaon
# 2       8 Bedroom House for sale in IMT Manesar         house     independent
# 3  3 Bedroom House for sale in Sector 15 Part 1         house     independent
# 4               4 BHK Flat in Sector 69 Gurgaon          flat    tulip violet
#
#    price  price_per_sqft    area  \
# 0   0.45          9000.0   500.0
# 1   0.50          8333.0   600.0
# 2   0.80          6666.0  1200.0
# 3   4.10         22331.0  1836.0
# 4   1.68          8358.0  2010.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                     Carpet area: 500 (46.45 sq.m.)        1         1
# 1  Built Up area: 600 (55.74 sq.m.)Carpet area: 5...        1         1
# 2                       Plot area 1200(111.48 sq.m.)        8         8
# 3  Plot area 204(170.57 sq.m.)Built Up area: 200 ...        3         3
# 4             Super Built up area 2010(186.74 sq.m.)        4         4
#
#   balcony                additionalRoom  \
# 0       1                 not available
# 1       1                 not available
# 2       2                 not available
# 3       2  pooja room,study room,others
# 4       2                 not available
#
#                                             address  floorNum      facing  \
# 0      Sector 8, Sector 8 Gurgaon, Gurgaon, Haryana       3.0        East
# 1  Sector 36a, Sector 36A Gurgaon, Gurgaon, Haryana       5.0         NaN
# 2                     IMT Manesar, Gurgaon, Haryana       1.0         NaN
# 3     Sector 15, Sector 15 Part 1, Gurgaon, Haryana       1.0  North-East
# 4          704, Sector 69 Gurgaon, Gurgaon, Haryana       7.0       North
#
#      agePossession                                    nearbyLocations  \
# 0        undefined                                                NaN
# 1        undefined                                                NaN
# 2  1 to 5 Year Old  ['Amba Clinic', 'Ragave Clinic', 'Sercare Clin...
# 3     10+ Year Old  ['Rajiv Chowk Mosque', 'Hanuman Mandir', 'Hdfc...
# 4  1 to 5 Year Old  ['Airia Mall Sector 68', 'Southern Peripheral ...
#
#                                          description  \
# 0  1bhk residential house for resale in sector 8 ...
# 1  Best in class property available at sector 36a...
# 2  Property earning monthly rent of 25000 appx.\n...
# 3  House for sale plot size 204 sqyard part one n...
# 4  This lovely 4 bhk apartment/flat in sector 69 ...
#
#                                       furnishDetails  \
# 0                                                NaN
# 1                                                NaN
# 2                                                 []
# 3  ['5 Wardrobe', '5 Fan', '1 Exhaust Fan', '3 Ge...
# 4  ['1 Modular Kitchen', 'No AC', 'No Bed', 'No C...
#
#                                             features  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  ['Maintenance Staff', 'Water Storage', 'Visito...
# 4  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
#
#                                               rating
# 0  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 1  ['Green Area4.5 out of 5', 'Construction4 out ...
# 2  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 3  ['Environment5 out of 5', 'Safety4 out of 5', ...
# 4  ['Green Area5 out of 5', 'Construction4 out of...

# %%
df.to_csv('gurgaon_properties_001.csv',index=False)
